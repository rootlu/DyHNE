# %%
import numpy as np
import pandas as pd
import os

# %%
data_dir = '../data/dblp/oriData/'
pa_data = pd.read_csv(os.path.join(data_dir,'paper_author.txt'),header=None,sep='\t')
pa_data
# Out:
#            0      1
# 0          0   7383
# 1          0   8503
# 2          1   2492
# 3          1  13694
# 4          1  13149
# 5          1  14307
# 6          1   6702
# 7          2  12246
# 8          3  12986
# 9          3     86
# 10         3   5284
# 11         3   2448
# 12         4  12246
# 13         5  12246
# 14         6   6696
# 15         6   8949
# 16         6   7416
# 17         6  12699
# 18         7  14090
# 19         7   8424
# 20         7   5040
# 21         7  12656
# 22         8   9941
# 23         8  13308
# 24         8  10324
# 25         9   2100
# 26         9   7700
# 27        10   1349
# 28        11  10615
# 29        11   6442
# ...      ...    ...
# 41764  14364   7445
# 41765  14364    898
# 41766  14365   2165
# 41767  14365   7604
# 41768  14365   8787
# 41769  14366   3467
# 41770  14367   6167
# 41771  14368  12574
# 41772  14368   2506
# 41773  14368    854
# 41774  14368   7182
# 41775  14368   4206
# 41776  14369  10992
# ...

# %%
pc_data = pd.read_csv(os.path.join(data_dir,'paper_conf.txt'),header=None,sep='\t')
pc_data
# Out:
#            0   1
# 0          0  14
# 1          1  17
# 2          2  10
# 3          3  10
# 4          4  10
# 5          5  10
# 6          6  10
# 7          7  17
# 8          8  13
# 9          9  18
# 10        10   5
# 11        11  18
# 12        12  18
# 13        13  18
# 14        14   5
# 15        15   8
# 16        16  14
# 17        17  14
# 18        18  14
# 19        19  14
# 20        20  14
# 21        21  18
# 22        22  18
# 23        23   2
# 24        24  18
# 25        25   2
# 26        26  18
# 27        27  12
# 28        28  12
# 29        29  14
# ...      ...  ..
# 14346  14346   5
# 14347  14347   5
# 14348  14348   5
# 14349  14349  13
# 14350  14350   7
# 14351  14351   7
# 14352  14352  15
# 14353  14353   5
# 14354  14354   7
# 14355  14355   7
# 14356  14356   7
# 14357  14357   7
# 14358  14358   7
# 14359  14359  14
# 14360  14360  10
# 14361  14361  15
# 14362  14362  15
# 14363  14363  15
# 14364  14364   5
# 14365  14365   4
# ...

# %%
len(set(pa_data[0])), len(set(pa_data[1]))
# Out:
# (14376, 14475)

# %%
A_pa_data = pa_data.copy()
A_pa_data
# Out:
#            0      1
# 0          0   7383
# 1          0   8503
# 2          1   2492
# 3          1  13694
# 4          1  13149
# 5          1  14307
# 6          1   6702
# 7          2  12246
# 8          3  12986
# 9          3     86
# 10         3   5284
# 11         3   2448
# 12         4  12246
# 13         5  12246
# 14         6   6696
# 15         6   8949
# 16         6   7416
# 17         6  12699
# 18         7  14090
# 19         7   8424
# 20         7   5040
# 21         7  12656
# 22         8   9941
# 23         8  13308
# 24         8  10324
# 25         9   2100
# 26         9   7700
# 27        10   1349
# 28        11  10615
# 29        11   6442
# ...      ...    ...
# 41764  14364   7445
# 41765  14364    898
# 41766  14365   2165
# 41767  14365   7604
# 41768  14365   8787
# 41769  14366   3467
# 41770  14367   6167
# 41771  14368  12574
# 41772  14368   2506
# 41773  14368    854
# 41774  14368   7182
# 41775  14368   4206
# 41776  14369  10992
# ...

# %%
A_pa_data.iloc[:, 1] = A_pa_data.iloc[:, 1].apply(lambda x:x+14376)

# %%
len(np.array(A_pa_data[1]).tolist()+np.array(A_pa_data[0]).tolist())
# Out:
# 83588

# %%
from scipy.sparse import csr_matrix
n = len(set(A_pa_data[0]))+len(set(A_pa_data[1]))
row = np.array(A_pa_data[0]).tolist()+np.array(A_pa_data[1]).tolist()
col = np.array(A_pa_data[1]).tolist()+np.array(A_pa_data[0]).tolist()
data = np.ones(len(row))
pa_mtx = csr_matrix((data, (row, col)), shape=(n, n))

# %%
pa_mtx.shape
# Out:
# (28851, 28851)

# %%
import scipy.io
scipy.io.savemat(os.path.join(data_dir,'pa_csr'),{"pa":pa_mtx})

# %%
scipy.io.savemat(os.path.join(data_dir,'ap_csr'),{"ap":pa_mtx.transpose()})

# %%
A_pc_data = pc_data.copy()
n_p = len(pc_data[0])
A_pc_data.iloc[:, 1] = A_pc_data.iloc[:, 1].apply(lambda x:x+n_p)
n_pc = len(set(A_pc_data[0]))+len(set(A_pc_data[1]))
row = np.array(A_pc_data[0]).tolist()+np.array(A_pc_data[1]).tolist()
col = np.array(A_pc_data[1]).tolist()+np.array(A_pc_data[0]).tolist()
data = np.ones(len(row))
pc_mtx = csr_matrix((data, (row, col)), shape=(n_pc, n_pc))
A_pc_data
# Out:
#            0      1
# 0          0  14390
# 1          1  14393
# 2          2  14386
# 3          3  14386
# 4          4  14386
# 5          5  14386
# 6          6  14386
# 7          7  14393
# 8          8  14389
# 9          9  14394
# 10        10  14381
# 11        11  14394
# 12        12  14394
# 13        13  14394
# 14        14  14381
# 15        15  14384
# 16        16  14390
# 17        17  14390
# 18        18  14390
# 19        19  14390
# 20        20  14390
# 21        21  14394
# 22        22  14394
# 23        23  14378
# 24        24  14394
# 25        25  14378
# 26        26  14394
# 27        27  14388
# 28        28  14388
# 29        29  14390
# ...      ...    ...
# 14346  14346  14381
# 14347  14347  14381
# 14348  14348  14381
# 14349  14349  14389
# 14350  14350  14383
# 14351  14351  14383
# 14352  14352  14391
# 14353  14353  14381
# 14354  14354  14383
# 14355  14355  14383
# 14356  14356  14383
# 14357  14357  14383
# 14358  14358  14383
# ...

# %%
np.array(A_pc_data[0]).tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e6b31d575e5> in <module>()
# ----> 1 np.array(A_pc_data[0]).tolist()
#
# NameError: name 'np' is not defined

# %%
scipy.io.savemat(os.path.join(data_dir,'pc_csr'),{"pc":pc_mtx})

# %%
# apc csr matrix
apc_data = pd.read_csv(os.path.join(data_dir,'apc.txt'),header=None,sep='\t')
A_apc_data = apc_data.copy()
A_apc_data
# Out:
#            0   1    2
# 0          0   5  1.0
# 1          1   3  1.0
# 2          1  12  1.0
# 3          1  13  1.0
# 4          2   3  1.0
# 5          2  19  1.0
# 6          3   3  1.0
# 7          3  19  1.0
# 8          4  17  1.0
# 9          5   3  1.0
# 10         5  11  1.0
# 11         6   3  1.0
# 12         7  13  1.0
# 13         8  18  1.0
# 14         9   3  1.0
# 15        10   2  5.0
# 16        10   3  2.0
# 17        10   5  4.0
# 18        10   7  1.0
# 19        10  15  1.0
# 20        10  16  1.0
# 21        11  17  1.0
# 22        12  10  1.0
# 23        12  14  4.0
# 24        13   3  1.0
# 25        13  10  2.0
# 26        13  12  1.0
# 27        14  10  1.0
# 28        15  10  1.0
# 29        16  10  2.0
# ...      ...  ..  ...
# 24465  14461   6  1.0
# 24466  14461   8  2.0
# 24467  14461  15  1.0
# 24468  14462  14  1.0
# 24469  14463   2  1.0
# 24470  14463   5  2.0
# 24471  14464   1  1.0
# 24472  14464   2  4.0
# 24473  14464   3  2.0
# ...

# %%
n_a = len(set(pa_data[1]))
A_apc_data.iloc[:, 1] = A_apc_data.iloc[:, 1].apply(lambda x:x+n_a)
A_apc_data
# Out:
#            0      1    2
# 0          0  14480  1.0
# 1          1  14478  1.0
# 2          1  14487  1.0
# 3          1  14488  1.0
# 4          2  14478  1.0
# 5          2  14494  1.0
# 6          3  14478  1.0
# 7          3  14494  1.0
# 8          4  14492  1.0
# 9          5  14478  1.0
# 10         5  14486  1.0
# 11         6  14478  1.0
# 12         7  14488  1.0
# 13         8  14493  1.0
# 14         9  14478  1.0
# 15        10  14477  5.0
# 16        10  14478  2.0
# 17        10  14480  4.0
# 18        10  14482  1.0
# 19        10  14490  1.0
# 20        10  14491  1.0
# 21        11  14492  1.0
# 22        12  14485  1.0
# 23        12  14489  4.0
# 24        13  14478  1.0
# 25        13  14485  2.0
# 26        13  14487  1.0
# 27        14  14485  1.0
# 28        15  14485  1.0
# 29        16  14485  2.0
# ...      ...    ...  ...
# 24465  14461  14481  1.0
# 24466  14461  14483  2.0
# 24467  14461  14490  1.0
# 24468  14462  14489  1.0
# 24469  14463  14477  1.0
# ...

# %%
A_apc_data[2]
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       5.0
# 16       2.0
# 17       4.0
# 18       1.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 23       4.0
# 24       1.0
# 25       2.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       2.0
#         ...
# 24465    1.0
# 24466    2.0
# 24467    1.0
# 24468    1.0
# 24469    1.0
# 24470    2.0
# 24471    1.0
# 24472    4.0
# 24473    2.0
# 24474    2.0
# 24475    1.0
# 24476    2.0
# 24477    1.0
# 24478    1.0
# 24479    1.0
# 24480    1.0
# 24481    1.0
# 24482    1.0
# 24483    2.0
# 24484    1.0
# 24485    1.0
# 24486    1.0
# 24487    1.0
# 24488    3.0
# 24489    1.0
# 24490    1.0
# 24491    1.0
# 24492    2.0
# 24493    2.0
# 24494    1.0
# Name: 2, Length: 24495, dtype: float64

# %%
n_apc = len(set(A_apc_data[0]))+len(set(A_apc_data[1]))
row = np.array(A_apc_data[0]).tolist()+np.array(A_apc_data[1]).tolist()
col = np.array(A_apc_data[1]).tolist()+np.array(A_apc_data[0]).tolist()
data = A_apc_data[2].tolist()+A_apc_data[2].tolist()
apc_mtx = csr_matrix((data, (row, col)), shape=(n_apc, n_apc))
np.nonzero(apc_mtx)
# Out:
# (array([    0,     1,     1, ..., 14494, 14494, 14494], dtype=int32),
#  array([14480, 14478, 14487, ..., 13875, 13905, 14357], dtype=int32))

# %%
scipy.io.savemat(os.path.join(data_dir,'apc_csr'),{"apc":apc_mtx})

# %%
# apt csr matrix
apt_data = pd.read_csv(os.path.join(data_dir,'apt.txt'),header=None,sep='\t')
A_apt_data = apt_data.copy()
A_apt_data
# Out:
#             0     1    2
# 0           0  1964  1.0
# 1           0  2174  1.0
# 2           0  2274  1.0
# 3           0  3507  1.0
# 4           0  5451  1.0
# 5           0  5858  1.0
# 6           0  6552  1.0
# 7           1   597  1.0
# 8           1   712  1.0
# 9           1   853  1.0
# 10          1   912  1.0
# 11          1  1160  1.0
# 12          1  2232  1.0
# 13          1  2274  1.0
# 14          1  2865  1.0
# 15          1  3486  1.0
# 16          1  4318  1.0
# 17          1  6231  1.0
# 18          1  6566  1.0
# 19          1  6824  1.0
# 20          1  7053  1.0
# 21          1  7439  1.0
# 22          1  7818  1.0
# 23          1  8453  1.0
# 24          1  8688  1.0
# 25          2  1160  1.0
# 26          2  2232  2.0
# 27          2  2511  1.0
# 28          2  3486  1.0
# 29          2  4318  1.0
# ...       ...   ...  ...
# 217108  14472  5301  1.0
# 217109  14473    73  1.0
# 217110  14473   526  1.0
# 217111  14473   614  1.0
# 217112  14473   805  1.0
# ...

# %%
n_a = len(set(pa_data[1]))
A_apt_data.iloc[:, 1] = A_apt_data.iloc[:, 1].apply(lambda x:x+n_a)
A_apt_data
# Out:
#             0      1    2
# 0           0  16439  1.0
# 1           0  16649  1.0
# 2           0  16749  1.0
# 3           0  17982  1.0
# 4           0  19926  1.0
# 5           0  20333  1.0
# 6           0  21027  1.0
# 7           1  15072  1.0
# 8           1  15187  1.0
# 9           1  15328  1.0
# 10          1  15387  1.0
# 11          1  15635  1.0
# 12          1  16707  1.0
# 13          1  16749  1.0
# 14          1  17340  1.0
# 15          1  17961  1.0
# 16          1  18793  1.0
# 17          1  20706  1.0
# 18          1  21041  1.0
# 19          1  21299  1.0
# 20          1  21528  1.0
# 21          1  21914  1.0
# 22          1  22293  1.0
# 23          1  22928  1.0
# 24          1  23163  1.0
# 25          2  15635  1.0
# 26          2  16707  2.0
# 27          2  16986  1.0
# 28          2  17961  1.0
# 29          2  18793  1.0
# ...       ...    ...  ...
# 217108  14472  19776  1.0
# 217109  14473  14548  1.0
# 217110  14473  15001  1.0
# ...

# %%
n_apt = len(set(A_apt_data[0]))+len(set(A_apt_data[1]))
row = np.array(A_apt_data[0]).tolist()+np.array(A_apt_data[1]).tolist()
col = np.array(A_apt_data[1]).tolist()+np.array(A_apt_data[0]).tolist()
data = A_apt_data[2].tolist()+A_apt_data[2].tolist()
apt_mtx = csr_matrix((data, (row, col)), shape=(n_apt, n_apt))
np.nonzero(apt_mtx)
# Out:
# (array([    0,     0,     0, ..., 23284, 23284, 23285], dtype=int32),
#  array([16439, 16649, 16749, ...,  4723, 12793, 11545], dtype=int32))

# %%
scipy.io.savemat(os.path.join(data_dir,'apt_csr'),{"apt":apt_mtx})

# %%
# apa csr matrx
apa_data = pd.read_csv(os.path.join(data_dir,'apa.txt'),header=None,sep='\t')
A_apa_data = apa_data.copy()
A_apa_data
# Out:
#            0      1    2
# 0          0      0  1.0
# 1          0   4793  1.0
# 2          0   7309  1.0
# 3          1      1  3.0
# 4          1      2  1.0
# 5          1      3  1.0
# 6          1    782  1.0
# 7          1   1856  1.0
# 8          1   1861  1.0
# 9          1   6813  1.0
# 10         1   9083  2.0
# 11         1   9084  1.0
# 12         1   9086  1.0
# 13         1  11635  1.0
# 14         1  13496  1.0
# 15         2      1  1.0
# 16         2      2  2.0
# 17         2      3  2.0
# 18         2    515  1.0
# 19         2    618  1.0
# 20         2   1861  1.0
# 21         2   6659  1.0
# 22         2   9070  1.0
# 23         2   9086  2.0
# 24         2  10236  1.0
# 25         2  10292  1.0
# 26         2  11635  1.0
# 27         2  13238  1.0
# 28         3      1  1.0
# 29         3      2  2.0
# ...      ...    ...  ...
# 94983  14469   8588  1.0
# 94984  14469  14469  1.0
# 94985  14470   1399  1.0
# 94986  14470   1417  1.0
# 94987  14470   2999  1.0
# ...

# %%
len(set(A_apa_data[0]))
# Out:
# 14475

# %%
n_apa = len(set(A_apa_data[0]))
row = np.array(A_apa_data[0]).tolist()
col = np.array(A_apa_data[1]).tolist()
data = A_apa_data[2].tolist()
apa_mtx = csr_matrix((data, (row, col)), shape=(n_apa, n_apa))
np.nonzero(apa_mtx)
# Out:
# (array([    0,     0,     0, ..., 14474, 14474, 14474], dtype=int32),
#  array([    0,  4793,  7309, ...,  5655,  9584, 14474], dtype=int32))

# %%
scipy.io.savemat(os.path.join(data_dir,'apa_csr'),{"apa":apa_mtx})

# %%
# apcpa csr matrx
apcpa_data = pd.read_csv(os.path.join(data_dir,'apcpa.txt'),header=None,sep='\t')
A_apcpa_data = apcpa_data.copy()
A_apcpa_data
# Out:
#               0      1    2
# 0             0      0  1.0
# 1             0     10  4.0
# 2             0     20  1.0
# 3             0     25  1.0
# 4             0     37  2.0
# 5             0     46  1.0
# 6             0     69  1.0
# 7             0     91  3.0
# 8             0     95  1.0
# 9             0     97  7.0
# 10            0     98  4.0
# 11            0    102  2.0
# 12            0    103  1.0
# 13            0    104  1.0
# 14            0    113  1.0
# 15            0    121  2.0
# 16            0    123  1.0
# 17            0    124  3.0
# 18            0    126  4.0
# 19            0    127  1.0
# 20            0    128  1.0
# 21            0    129  1.0
# 22            0    131  2.0
# 23            0    148  1.0
# 24            0    151  2.0
# 25            0    152  3.0
# 26            0    154  1.0
# 27            0    160  1.0
# 28            0    161  1.0
# 29            0    177  1.0
# ...         ...    ...  ...
# 38905143  14474  14286  1.0
# ...

# %%
n_apcpa = len(set(A_apcpa_data[0]))
row = np.array(A_apcpa_data[0]).tolist()
col = np.array(A_apcpa_data[1]).tolist()
data = A_apcpa_data[2].tolist()
apcpa_mtx = csr_matrix((data, (row, col)), shape=(n_apcpa, n_apcpa))
np.nonzero(apcpa_mtx)
# Out:
# (array([    0,     0,     0, ..., 14474, 14474, 14474], dtype=int32),
#  array([    0,    10,    20, ..., 14469, 14470, 14474], dtype=int32))

# %%
scipy.io.savemat(os.path.join(data_dir,'apcpa_csr'),{"apcpa":apcpa_mtx})

# %%
# aptpa csr matrx
aptpa_data = pd.read_csv(os.path.join(data_dir,'aptpa.txt'),header=None,sep='\t')
A_aptpa_data = aptpa_data.copy()
A_aptpa_data
# Out:
#               0      1     2
# 0             0      0   7.0
# 1             0      1   1.0
# 2             0     10   1.0
# 3             0     20   1.0
# 4             0     24   3.0
# 5             0     25   1.0
# 6             0     26   1.0
# 7             0     37   1.0
# 8             0     43   1.0
# 9             0     50   1.0
# 10            0     51   1.0
# 11            0     52   1.0
# 12            0     53   1.0
# 13            0     56   1.0
# 14            0     57   1.0
# 15            0     61   2.0
# 16            0     70   3.0
# 17            0     79   1.0
# 18            0     80   2.0
# 19            0     83   1.0
# 20            0     84  11.0
# 21            0     86   5.0
# 22            0     91   8.0
# 23            0     94   1.0
# 24            0     97   1.0
# 25            0     98   1.0
# 26            0    101   1.0
# 27            0    102   1.0
# 28            0    104   2.0
# 29            0    110   1.0
# ...         ...    ...   ...
# ...

# %%
n_aptpa = len(set(A_aptpa_data[0]))
row = np.array(A_aptpa_data[0]).tolist()
col = np.array(A_aptpa_data[1]).tolist()
data = A_aptpa_data[2].tolist()
aptpa_mtx = csr_matrix((data, (row, col)), shape=(n_aptpa, n_aptpa))
np.nonzero(aptpa_mtx)
# Out:
# (array([    0,     0,     0, ..., 14474, 14474, 14474], dtype=int32),
#  array([    0,     1,    10, ..., 14464, 14470, 14474], dtype=int32))

# %%
scipy.io.savemat(os.path.join(data_dir,'aptpa_csr'),{"aptpa":aptpa_mtx})
